# %% [markdown]
# ## Data quality and preparation:
# - Merge files and filter for the last 10 years.
#
# Cleaning:
# - Columns that mainly have NULLs
# - Duplicates
# - Datatypes
# - Outliers
# - Add in first column "City" and add in city name in lowercase.
